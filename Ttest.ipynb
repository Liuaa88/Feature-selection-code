# %%
import pandas as pd
from scipy.stats import ttest_ind,levene

#分组
dataFile = "D:\\0_0.3CC\without_ID_0.3cc_0.7（seed100）.csv"
data = pd.read_csv(dataFile)
data_a = data[data["TSS"] == 0] #选出label=0的那些行
data_b = data[data["TSS"] == 1] #选出label=1的那些行
data_a
data_b

#划分x和y
x_a = data_a.iloc[:,0:-1] #0至-1列，不包括-1列
y_a = data["TSS"]  #label列，即-1列
x_b = data_b.iloc[:,0:-1]
y_b = data_b["TSS"]
print(x_a.shape,x_b.shape) #看行列数

#单列t检验
#levene(x_a["A"],x_b["A"]) #求A列的pvalue值
#ttest_ind(x_a["A"],x_b["A"],equal_var=False) #求出pvalue值

#循环t检验
colNamesSel_t = []
for colName in x_a.columns[:]:    #选取所有列
    if levene(x_a[colName],x_b[colName])[1] > 0.05: #把每一列进行levene,然后选出第1列(即pvalue值)的值> 0.05 的列(即具有方差齐性即符合正态性要求)
        if ttest_ind(x_a[colName],x_b[colName])[1] < 0.05:
            colNamesSel_t.append(colName) #选出第1列(即pvalue值)的值< 0.05 的列，说明两个样本存在显著的差异
    else:
        if ttest_ind(x_a[colName],x_b[colName],equal_var=False)[1] < 0.05: #具有显著的差异
              colNamesSel_t.append(colName)
print(len(colNamesSel_t)) #打印出长度，看选中25列
print(colNamesSel_t)  #看看选中的列
# Out:
# (31, 1702) (81, 1702)
# D:\Users\liu\anaconda3\lib\site-packages\scipy\stats\morestats.py:2603: RuntimeWarning: invalid value encountered in double_scalars
#   W = numer / denom
# 298
# ...

# %%
import pandas as pd
import xlsxwriter
dataFile = "D:\\0_0.3CC\without_ID_0.3cc_0.7（seed100）.csv"
a = pd.read_csv(dataFile)

# %%
b = a[['TSS', 'DWI_original_shape_Flatness', 'DWI_original_shape_Sphericity', 'DWI_original_firstorder_90Percentile', 'DWI_original_firstorder_Entropy', 'DWI_original_firstorder_InterquartileRange', 'DWI_original_firstorder_Maximum', 'DWI_original_firstorder_MeanAbsoluteDeviation', 'DWI_original_firstorder_Range', 'DWI_original_firstorder_RobustMeanAbsoluteDeviation', 'DWI_original_firstorder_Skewness', 'DWI_original_firstorder_Uniformity', 'DWI_original_firstorder_Variance', 'DWI_original_glcm_Contrast', 'DWI_original_glcm_Correlation', 'DWI_original_glcm_DifferenceAverage', 'DWI_original_glcm_DifferenceVariance', 'DWI_original_glcm_Id', 'DWI_original_glcm_Idm', 'DWI_original_glcm_Idmn', 'DWI_original_glcm_Idn', 'DWI_original_glcm_Imc1', 'DWI_original_glcm_Imc2', 'DWI_original_glcm_InverseVariance', 'DWI_original_glcm_MCC', 'DWI_original_glcm_SumSquares', 'DWI_original_gldm_GrayLevelVariance', 'DWI_original_gldm_SmallDependenceEmphasis', 'DWI_original_glrlm_GrayLevelNonUniformityNormalized', 'DWI_original_glrlm_GrayLevelVariance', 'DWI_original_glrlm_LongRunEmphasis', 'DWI_original_glrlm_RunLengthNonUniformityNormalized', 'DWI_original_glrlm_RunPercentage', 'DWI_original_glrlm_RunVariance', 'DWI_original_glrlm_ShortRunEmphasis', 'DWI_original_glszm_GrayLevelNonUniformityNormalized', 'DWI_original_glszm_GrayLevelVariance', 'DWI_original_glszm_ZonePercentage', 'DWI_original_ngtdm_Contrast', 'DWI_wavelet-LLH_glcm_Correlation', 'DWI_wavelet-LLH_glcm_Id', 'DWI_wavelet-LLH_glcm_Idm', 'DWI_wavelet-LLH_glcm_Idmn', 'DWI_wavelet-LLH_glcm_Idn', 'DWI_wavelet-LLH_glcm_Imc1', 'DWI_wavelet-LLH_glcm_InverseVariance', 'DWI_wavelet-LLH_glrlm_LongRunEmphasis', 'DWI_wavelet-LLH_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-LLH_glrlm_RunPercentage', 'DWI_wavelet-LLH_glrlm_RunVariance', 'DWI_wavelet-LLH_glrlm_ShortRunEmphasis', 'DWI_wavelet-LLH_ngtdm_Coarseness', 'DWI_wavelet-LHL_firstorder_Entropy', 'DWI_wavelet-LHL_firstorder_InterquartileRange', 'DWI_wavelet-LHL_firstorder_Median', 'DWI_wavelet-LHL_firstorder_Minimum', 'DWI_wavelet-LHL_firstorder_Uniformity', 'DWI_wavelet-LHL_glcm_Contrast', 'DWI_wavelet-LHL_glcm_DifferenceAverage', 'DWI_wavelet-LHL_glcm_DifferenceEntropy', 'DWI_wavelet-LHL_glcm_DifferenceVariance', 'DWI_wavelet-LHL_glcm_Id', 'DWI_wavelet-LHL_glcm_Idm', 'DWI_wavelet-LHL_glcm_InverseVariance', 'DWI_wavelet-LHL_glcm_JointAverage', 'DWI_wavelet-LHL_glcm_SumAverage', 'DWI_wavelet-LHL_glrlm_LongRunEmphasis', 'DWI_wavelet-LHL_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-LHL_glrlm_RunPercentage', 'DWI_wavelet-LHL_glrlm_RunVariance', 'DWI_wavelet-LHL_glrlm_ShortRunEmphasis', 'DWI_wavelet-LHL_glrlm_ShortRunHighGrayLevelEmphasis', 'DWI_wavelet-LHL_glszm_HighGrayLevelZoneEmphasis', 'DWI_wavelet-LHH_glcm_Correlation', 'DWI_wavelet-LHH_glcm_Id', 'DWI_wavelet-LHH_glcm_Idm', 'DWI_wavelet-LHH_glcm_Imc1', 'DWI_wavelet-LHH_glcm_InverseVariance', 'DWI_wavelet-LHH_glrlm_LongRunEmphasis', 'DWI_wavelet-LHH_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-LHH_glrlm_RunPercentage', 'DWI_wavelet-LHH_glrlm_RunVariance', 'DWI_wavelet-LHH_glrlm_ShortRunEmphasis', 'DWI_wavelet-HLL_firstorder_10Percentile', 'DWI_wavelet-HLL_firstorder_90Percentile', 'DWI_wavelet-HLL_firstorder_Entropy', 'DWI_wavelet-HLL_firstorder_InterquartileRange', 'DWI_wavelet-HLL_firstorder_MeanAbsoluteDeviation', 'DWI_wavelet-HLL_firstorder_Mean', 'DWI_wavelet-HLL_firstorder_Median', 'DWI_wavelet-HLL_firstorder_Minimum', 'DWI_wavelet-HLL_firstorder_Range', 'DWI_wavelet-HLL_firstorder_RobustMeanAbsoluteDeviation', 'DWI_wavelet-HLL_firstorder_RootMeanSquared', 'DWI_wavelet-HLL_firstorder_Uniformity', 'DWI_wavelet-HLL_firstorder_Variance', 'DWI_wavelet-HLL_glcm_ClusterTendency', 'DWI_wavelet-HLL_glcm_Contrast', 'DWI_wavelet-HLL_glcm_DifferenceAverage', 'DWI_wavelet-HLL_glcm_DifferenceEntropy', 'DWI_wavelet-HLL_glcm_DifferenceVariance', 'DWI_wavelet-HLL_glcm_Id', 'DWI_wavelet-HLL_glcm_Idm', 'DWI_wavelet-HLL_glcm_Imc1', 'DWI_wavelet-HLL_glcm_Imc2', 'DWI_wavelet-HLL_glcm_InverseVariance', 'DWI_wavelet-HLL_glcm_MCC', 'DWI_wavelet-HLL_glcm_SumSquares', 'DWI_wavelet-HLL_gldm_GrayLevelVariance', 'DWI_wavelet-HLL_gldm_SmallDependenceHighGrayLevelEmphasis', 'DWI_wavelet-HLL_glrlm_GrayLevelNonUniformityNormalized', 'DWI_wavelet-HLL_glrlm_GrayLevelVariance', 'DWI_wavelet-HLL_glrlm_LongRunEmphasis', 'DWI_wavelet-HLL_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-HLL_glrlm_RunPercentage', 'DWI_wavelet-HLL_glrlm_RunVariance', 'DWI_wavelet-HLL_glrlm_ShortRunEmphasis', 'DWI_wavelet-HLL_glszm_GrayLevelNonUniformityNormalized', 'DWI_wavelet-HLL_glszm_GrayLevelVariance', 'DWI_wavelet-HLL_glszm_LargeAreaLowGrayLevelEmphasis', 'DWI_wavelet-HLL_ngtdm_Busyness', 'DWI_wavelet-HLL_ngtdm_Contrast', 'DWI_wavelet-HLL_ngtdm_Strength', 'DWI_wavelet-HLH_firstorder_Median', 'DWI_wavelet-HLH_glcm_Correlation', 'DWI_wavelet-HLH_glcm_DifferenceAverage', 'DWI_wavelet-HLH_glcm_Id', 'DWI_wavelet-HLH_glcm_Idm', 'DWI_wavelet-HLH_glcm_Imc1', 'DWI_wavelet-HLH_glcm_Imc2', 'DWI_wavelet-HLH_glcm_InverseVariance', 'DWI_wavelet-HLH_glrlm_LongRunEmphasis', 'DWI_wavelet-HLH_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-HLH_glrlm_RunPercentage', 'DWI_wavelet-HLH_glrlm_RunVariance', 'DWI_wavelet-HLH_glrlm_ShortRunEmphasis', 'DWI_wavelet-HLH_ngtdm_Contrast', 'DWI_wavelet-HHL_glcm_Imc1', 'DWI_wavelet-HHL_glcm_Imc2', 'DWI_wavelet-HHL_glcm_MCC', 'DWI_wavelet-HHL_gldm_DependenceNonUniformityNormalized', 'DWI_wavelet-HHL_glrlm_LongRunEmphasis', 'DWI_wavelet-HHL_glrlm_RunEntropy', 'DWI_wavelet-HHL_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-HHL_glrlm_RunPercentage', 'DWI_wavelet-HHL_glrlm_RunVariance', 'DWI_wavelet-HHL_glrlm_ShortRunEmphasis', 'DWI_wavelet-HHH_glcm_Correlation', 'DWI_wavelet-HHH_glcm_DifferenceAverage', 'DWI_wavelet-HHH_glcm_Id', 'DWI_wavelet-HHH_glcm_Idm', 'DWI_wavelet-HHH_glcm_Idn', 'DWI_wavelet-HHH_glcm_InverseVariance', 'DWI_wavelet-HHH_glrlm_LongRunEmphasis', 'DWI_wavelet-HHH_glrlm_LongRunHighGrayLevelEmphasis', 'DWI_wavelet-HHH_glrlm_RunEntropy', 'DWI_wavelet-HHH_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-HHH_glrlm_RunPercentage', 'DWI_wavelet-HHH_glrlm_RunVariance', 'DWI_wavelet-HHH_glrlm_ShortRunEmphasis', 'DWI_wavelet-HHH_glrlm_ShortRunLowGrayLevelEmphasis', 'DWI_wavelet-LLL_firstorder_Skewness', 'DWI_wavelet-LLL_glcm_Correlation', 'DWI_wavelet-LLL_glcm_DifferenceAverage', 'DWI_wavelet-LLL_glcm_Id', 'DWI_wavelet-LLL_glcm_Idm', 'DWI_wavelet-LLL_glcm_Idn', 'DWI_wavelet-LLL_glcm_Imc1', 'DWI_wavelet-LLL_glcm_InverseVariance', 'DWI_wavelet-LLL_glcm_MCC', 'DWI_wavelet-LLL_gldm_DependenceNonUniformityNormalized', 'DWI_wavelet-LLL_gldm_DependenceVariance', 'DWI_wavelet-LLL_gldm_LargeDependenceEmphasis', 'DWI_wavelet-LLL_gldm_SmallDependenceEmphasis', 'DWI_wavelet-LLL_glrlm_LongRunEmphasis', 'DWI_wavelet-LLL_glrlm_RunLengthNonUniformityNormalized', 'DWI_wavelet-LLL_glrlm_RunPercentage', 'DWI_wavelet-LLL_glrlm_RunVariance', 'DWI_wavelet-LLL_glrlm_ShortRunEmphasis', 'DWI_wavelet-LLL_glszm_LargeAreaEmphasis', 'DWI_wavelet-LLL_glszm_SizeZoneNonUniformityNormalized', 'DWI_wavelet-LLL_glszm_SmallAreaEmphasis', 'DWI_wavelet-LLL_glszm_ZonePercentage', 'ADC_original_shape_Flatness', 'ADC_original_shape_Sphericity', 'ADC_original_firstorder_10Percentile', 'ADC_original_firstorder_90Percentile', 'ADC_original_firstorder_Maximum', 'ADC_original_firstorder_Mean', 'ADC_original_firstorder_Median', 'ADC_original_firstorder_Minimum', 'ADC_original_firstorder_RootMeanSquared', 'ADC_original_firstorder_Skewness', 'ADC_original_glcm_ClusterProminence', 'ADC_original_glcm_ClusterShade', 'ADC_original_glcm_ClusterTendency', 'ADC_original_glcm_Correlation', 'ADC_original_glcm_Id', 'ADC_original_glcm_Idm', 'ADC_original_glcm_Idmn', 'ADC_original_glcm_Idn', 'ADC_original_glcm_InverseVariance', 'ADC_original_glcm_SumEntropy', 'ADC_original_glrlm_LongRunEmphasis', 'ADC_original_glrlm_RunEntropy', 'ADC_original_glrlm_RunLengthNonUniformityNormalized', 'ADC_original_glrlm_RunPercentage', 'ADC_original_glrlm_RunVariance', 'ADC_original_glrlm_ShortRunEmphasis', 'ADC_original_glszm_GrayLevelVariance', 'ADC_original_ngtdm_Strength', 'ADC_wavelet-LLH_glcm_Correlation', 'ADC_wavelet-LLH_glcm_Idmn', 'ADC_wavelet-LLH_glcm_Idn', 'ADC_wavelet-LLH_glcm_SumEntropy', 'ADC_wavelet-LHL_firstorder_Maximum', 'ADC_wavelet-LHL_glcm_ClusterTendency', 'ADC_wavelet-LHL_glcm_DifferenceVariance', 'ADC_wavelet-LHL_glcm_JointEntropy', 'ADC_wavelet-LHL_glcm_SumEntropy', 'ADC_wavelet-LHL_gldm_LargeDependenceLowGrayLevelEmphasis', 'ADC_wavelet-LHL_glrlm_GrayLevelVariance', 'ADC_wavelet-LHL_glrlm_RunEntropy', 'ADC_wavelet-LHL_glrlm_RunLengthNonUniformityNormalized', 'ADC_wavelet-LHL_glrlm_RunPercentage', 'ADC_wavelet-LHL_glrlm_ShortRunEmphasis', 'ADC_wavelet-LHH_glcm_Correlation', 'ADC_wavelet-LHH_glcm_SumEntropy', 'ADC_wavelet-LHH_glrlm_LongRunEmphasis', 'ADC_wavelet-LHH_glrlm_RunEntropy', 'ADC_wavelet-LHH_glrlm_RunLengthNonUniformityNormalized', 'ADC_wavelet-LHH_glrlm_RunPercentage', 'ADC_wavelet-LHH_glrlm_RunVariance', 'ADC_wavelet-LHH_glrlm_ShortRunEmphasis', 'ADC_wavelet-LHH_glszm_SizeZoneNonUniformityNormalized', 'ADC_wavelet-LHH_glszm_SmallAreaEmphasis', 'ADC_wavelet-HLL_glcm_JointEntropy', 'ADC_wavelet-HLL_glcm_SumEntropy', 'ADC_wavelet-HLL_glrlm_RunEntropy', 'ADC_wavelet-HLL_glrlm_RunLengthNonUniformityNormalized', 'ADC_wavelet-HLL_glrlm_RunPercentage', 'ADC_wavelet-HLL_glrlm_ShortRunEmphasis', 'ADC_wavelet-HLH_glcm_Correlation', 'ADC_wavelet-HLH_glrlm_LongRunEmphasis', 'ADC_wavelet-HLH_glrlm_RunLengthNonUniformityNormalized', 'ADC_wavelet-HLH_glrlm_RunPercentage', 'ADC_wavelet-HLH_glrlm_RunVariance', 'ADC_wavelet-HLH_glrlm_ShortRunEmphasis', 'ADC_wavelet-HHL_firstorder_Entropy', 'ADC_wavelet-HHL_firstorder_RootMeanSquared', 'ADC_wavelet-HHL_firstorder_Skewness', 'ADC_wavelet-HHL_firstorder_Uniformity', 'ADC_wavelet-HHL_firstorder_Variance', 'ADC_wavelet-HHL_glcm_ClusterTendency', 'ADC_wavelet-HHL_glcm_Contrast', 'ADC_wavelet-HHL_glcm_DifferenceAverage', 'ADC_wavelet-HHL_glcm_DifferenceEntropy', 'ADC_wavelet-HHL_glcm_DifferenceVariance', 'ADC_wavelet-HHL_glcm_InverseVariance', 'ADC_wavelet-HHL_glcm_JointEnergy', 'ADC_wavelet-HHL_glcm_JointEntropy', 'ADC_wavelet-HHL_glcm_MaximumProbability', 'ADC_wavelet-HHL_glcm_SumEntropy', 'ADC_wavelet-HHL_glcm_SumSquares', 'ADC_wavelet-HHL_gldm_GrayLevelVariance', 'ADC_wavelet-HHL_gldm_SmallDependenceEmphasis', 'ADC_wavelet-HHL_gldm_SmallDependenceHighGrayLevelEmphasis', 'ADC_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized', 'ADC_wavelet-HHL_glrlm_GrayLevelVariance', 'ADC_wavelet-HHL_glrlm_RunEntropy', 'ADC_wavelet-HHL_glrlm_RunPercentage', 'ADC_wavelet-HHL_glrlm_RunVariance', 'ADC_wavelet-HHL_glszm_GrayLevelNonUniformityNormalized', 'ADC_wavelet-HHL_glszm_GrayLevelVariance', 'ADC_wavelet-HHL_ngtdm_Complexity', 'ADC_wavelet-HHL_ngtdm_Strength', 'ADC_wavelet-HHH_glcm_Correlation', 'ADC_wavelet-HHH_glcm_InverseVariance', 'ADC_wavelet-HHH_glrlm_LongRunEmphasis', 'ADC_wavelet-HHH_glrlm_RunEntropy', 'ADC_wavelet-HHH_glrlm_RunLengthNonUniformityNormalized', 'ADC_wavelet-HHH_glrlm_RunPercentage', 'ADC_wavelet-HHH_glrlm_RunVariance', 'ADC_wavelet-HHH_glrlm_ShortRunEmphasis', 'ADC_wavelet-LLL_firstorder_10Percentile', 'ADC_wavelet-LLL_firstorder_90Percentile', 'ADC_wavelet-LLL_firstorder_Maximum', 'ADC_wavelet-LLL_firstorder_Mean', 'ADC_wavelet-LLL_firstorder_Median', 'ADC_wavelet-LLL_firstorder_RootMeanSquared', 'ADC_wavelet-LLL_glcm_Autocorrelation', 'ADC_wavelet-LLL_glcm_Correlation', 'ADC_wavelet-LLL_glcm_Idn', 'ADC_wavelet-LLL_glcm_JointAverage', 'ADC_wavelet-LLL_glcm_SumAverage', 'ADC_wavelet-LLL_glcm_SumEntropy', 'ADC_wavelet-LLL_glrlm_RunLengthNonUniformityNormalized', 'ADC_wavelet-LLL_glrlm_ShortRunEmphasis']]

# %%
b.to_csv("D:\\0_0.3CC\without_ID_0.3cc_0.7（seed100）_T.csv")
